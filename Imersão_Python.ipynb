# %% [markdown]
# Aula 2 - Importação

# %%
import pandas as pd

# %%
df_principal = pd.read_excel("/content/base de acoes_pura.xlsx", sheet_name="Principal")
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia  Var. Sem.  Var. Mês  Var. Ano  \
# 0   USIM5 2024-01-26         9.50      5.20      11.76      2.26      2.26
# 1   CMIN3 2024-01-26         6.82      2.40       2.40    -12.11    -12.11
# 2   PETR3 2024-01-26        41.96      2.19       7.73      7.64      7.64
# 3   SUZB3 2024-01-26        52.91      2.04       2.14     -4.89     -4.89
# 4   CPFE3 2024-01-26        37.10      2.03       2.49     -3.66     -3.66
# ..    ...        ...          ...       ...        ...       ...       ...
# 76  CRFB3 2024-01-26        10.71     -2.45      -9.47    -13.98    -13.98
# 77  BHIA3 2024-01-26         8.70     -2.46      -6.95    -23.55    -23.55
# 78  RENT3 2024-01-26        56.24     -3.63      -6.41    -11.57    -11.57
# 79  CVCB3 2024-01-26         3.07     -4.36      -5.54    -12.29    -12.29
# 80  GOLL4 2024-01-26         5.92     -8.07     -15.91    -34.00    -34.00
#
# ...

# %%
df_total_acoes = pd.read_excel("/content/base de acoes_pura.xlsx", sheet_name="Total_de_acoes")
df_total_acoes
# Out:
#                       Código  Qtde. Teórica
# 0                      RRRP3   2.356656e+08
# 1                      ALOS3   5.326166e+08
# 2                      ALPA4   1.767340e+08
# 3                      ABEV3   4.394246e+09
# 4                      ARZZ3   6.230589e+07
# ..                       ...            ...
# 84                     VBBR3   1.114413e+09
# 85                     WEGE3   1.481593e+09
# 86                     YDUQ3   2.893479e+08
# 87  Quantidade Teórica Total   9.637210e+10
# 88                   Redutor   1.704785e+07
#
# [89 rows x 2 columns]

# %%
df_ticker = pd.read_excel("/content/base de acoes_pura.xlsx", sheet_name="Ticker")
df_ticker
# Out:
#     Ticker            Nome
# 0    MGLU3  Magazine Luiza
# 1    HAPV3         Hapvida
# 2    PETR4       Petrobras
# 3    B3SA3              B3
# 4    USIM5        Usiminas
# ..     ...             ...
# 530  TKNO3           Tekno
# 531  COCE6          Coelce
# 532  MGEL3         Mangels
# 533  CTSA8      Santanense
# 534  MMAQ4   Minasmáquinas
#
# [535 rows x 2 columns]

# %%
df_chatgpt = pd.read_excel("/content/base de acoes_pura.xlsx", sheet_name="Chatgpt")
df_chatgpt
# Out:
#      Nome da empresa           Segmento  Idade (anos)
# 0           Usiminas         Siderurgia            60
# 1      CSN Mineração          Mineração             8
# 2          Petrobras           Petróleo            69
# 3             Suzano   Papel e Celulose            94
# 4       CPFL Energia            Energia           109
# ..               ...                ...           ...
# 76  Carrefour Brasil             Varejo            37
# 77       Casas Bahia             Varejo            95
# 78          Localiza  Aluguel de Carros            49
# 79               CVC            Turismo            50
# 80               GOL            Aviação            20
#
# [81 rows x 3 columns]
